# %% [markdown]
# # **Pre-Processing**

# %% [markdown]
# **Import Dataset**

# %%
import pandas as pd

df = pd.read_csv("Dataset/kplus_reviews_translated.csv")
df
# Out:
#                         at                                            content  \
# 0      2025-09-21 05:18:41                                          รวดเร็วดี
# 1      2025-09-21 04:27:43                              ชอบครับเร็วทันใจจริงๆ
# 2      2025-09-21 03:56:01                                สแกนใบหน้ายากชิบหาย
# 3      2025-09-21 03:37:50                แย่จัด รีเซ็ทเครื่องแล้วทำแอบไม่ได้
# 4      2025-09-21 02:24:04                                                 ดี
# ...                    ...                                                ...
# 99995  2021-06-04 06:14:35               จะเข้าใช้งานก็เข้าไม่ได้ คือไรวะ กาก
# 99996  2021-06-04 06:13:43  เข้าแอปไม่ได้ ลบแล้วโหลดใหม่ ชอบบอกว่ากรุณาทำร...
# 99997  2021-06-04 06:08:17                                      แอพช้าไปหน่อย
# 99998  2021-06-04 06:02:29                                             ดีครับ
# 99999  2021-06-04 05:53:52  ทำไมเข้าแอปไม่ได้มาหลายวันแล้ว มันขึ้นบอกว่าให...
#
#                                       content_translated
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 99995           I can't log in and use it. What's wrong?
# 99996  Can't enter the app Delete and reload I like t...
# 99997                             The app is a bit slow.
# 99998                                               good
# 99999  Why haven't I been able to access the app for ...
#
# [100000 rows x 3 columns]

# %% [markdown]
# **Slang Words Normalization & Text Cleaning**

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.3)
# Requirement already satisfied: pyahocorasick in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from textsearch>=0.0.21->contractions) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
slang_dict = {
    "kasikorn bank": "bank",
    "k plus": "app",
    "j plus": "app",
    "log in": "login",
    "log on": "login",
    "log out": "logout",
    "top up": "topup",

    "application": "app",
    "e-wallet": "electronic wallet",
    "ewallet": "electronic wallet",
    "m-banking": "mobile banking",
    "mbanking": "mobile banking",
    "top-up": "topup",
    "k-plus": "app",
    "kplus": "app",
    "k.plus": "app",
    "kasikorn": "bank"
}

# %%
import re
import contractions

def clean_text(text):
    if pd.isna(text):
        return ""
    
    text = str(text).lower()
    for slang, formal in slang_dict.items():
        text = re.sub(r'\b' + slang + r'\b', formal, text)
    text = re.sub(r'\b(\w+)(?:\s+\1\b)+', r'\1', text)    # Remove repeated words
    text = contractions.fix(text)                         # Expand contractions 
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)   # Remove URL
    text = re.sub(r'@\w+|#\w+', '', text)                 # Remove mentions & hashtags
    text = re.sub(r'[^a-z\s]', ' ', text)                 # Remove numbers, punctuation, and emojis
    text = re.sub(r'\s+', ' ', text).strip()              # Remove extra spaces
    return text

df['cleaned'] = df['content_translated'].apply(clean_text)
df
# Out:
#                         at                                            content  \
# 0      2025-09-21 05:18:41                                          รวดเร็วดี
# 1      2025-09-21 04:27:43                              ชอบครับเร็วทันใจจริงๆ
# 2      2025-09-21 03:56:01                                สแกนใบหน้ายากชิบหาย
# 3      2025-09-21 03:37:50                แย่จัด รีเซ็ทเครื่องแล้วทำแอบไม่ได้
# 4      2025-09-21 02:24:04                                                 ดี
# ...                    ...                                                ...
# 99995  2021-06-04 06:14:35               จะเข้าใช้งานก็เข้าไม่ได้ คือไรวะ กาก
# 99996  2021-06-04 06:13:43  เข้าแอปไม่ได้ ลบแล้วโหลดใหม่ ชอบบอกว่ากรุณาทำร...
# 99997  2021-06-04 06:08:17                                      แอพช้าไปหน่อย
# 99998  2021-06-04 06:02:29                                             ดีครับ
# 99999  2021-06-04 05:53:52  ทำไมเข้าแอปไม่ได้มาหลายวันแล้ว มันขึ้นบอกว่าให...
#
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 99995           I can't log in and use it. What's wrong?
# 99996  Can't enter the app Delete and reload I like t...
# 99997                             The app is a bit slow.
# 99998                                               good
# 99999  Why haven't I been able to access the app for ...
#
#                                                  cleaned
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 99995            i cannot login and use it what is wrong
# 99996  cannot enter the app delete and reload i like ...
# 99997                              the app is a bit slow
# 99998                                               good
# 99999  why have not i been able to access the app for...
#
# [99916 rows x 4 columns]

# %% [markdown]
# **Droping Empty Rows**

# %% [markdown]
# Many reviews contain only emojis, so after text cleaning, that column becomes empty.

# %%
emptyRow = len(df[df['cleaned'] == ""])
print(f"Number of empty rows (but not NaN): {emptyRow}")
# Out:
# Number of empty rows (but not NaN): 977

# %%
import numpy as np
df['cleaned'].replace("", np.nan, inplace=True)
df.dropna(subset=['cleaned'], inplace=True)
print("Number of rows after dropping null values:", len(df))
# Out:
# Number of rows after dropping null values: 98939
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\2127933692.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cleaned'].replace("", np.nan, inplace=True)

# %% [markdown]
# **Tokenize**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\A.ANGGADIPA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

df['tokens'] = df['cleaned'].apply(word_tokenize)
df
# Out:
#                         at                                            content  \
# 0      2025-09-21 05:18:41                                          รวดเร็วดี
# 1      2025-09-21 04:27:43                              ชอบครับเร็วทันใจจริงๆ
# 2      2025-09-21 03:56:01                                สแกนใบหน้ายากชิบหาย
# 3      2025-09-21 03:37:50                แย่จัด รีเซ็ทเครื่องแล้วทำแอบไม่ได้
# 4      2025-09-21 02:24:04                                                 ดี
# ...                    ...                                                ...
# 99995  2021-06-04 06:14:35               จะเข้าใช้งานก็เข้าไม่ได้ คือไรวะ กาก
# 99996  2021-06-04 06:13:43  เข้าแอปไม่ได้ ลบแล้วโหลดใหม่ ชอบบอกว่ากรุณาทำร...
# 99997  2021-06-04 06:08:17                                      แอพช้าไปหน่อย
# 99998  2021-06-04 06:02:29                                             ดีครับ
# 99999  2021-06-04 05:53:52  ทำไมเข้าแอปไม่ได้มาหลายวันแล้ว มันขึ้นบอกว่าให...
#
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 99995           I can't log in and use it. What's wrong?
# 99996  Can't enter the app Delete and reload I like t...
# 99997                             The app is a bit slow.
# 99998                                               good
# 99999  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 99995            i cannot login and use it what is wrong
# 99996  cannot enter the app delete and reload i like ...
# 99997                              the app is a bit slow
# 99998                                               good
# 99999  why have not i been able to access the app for...
#
#                                                   tokens
# 0                                           [very, fast]
# 1                    [i, like, it, it, is, really, fast]
# 2                       [scanning, faces, is, difficult]
# 3      [very, bad, reset, the, device, and, can, not,...
# 4                                                 [good]
# ...                                                  ...
# 99995  [i, can, not, login, and, use, it, what, is, w...
# 99996  [can, not, enter, the, app, delete, and, reloa...
# 99997                       [the, app, is, a, bit, slow]
# 99998                                             [good]
# 99999  [why, have, not, i, been, able, to, access, th...
#
# [98939 rows x 5 columns]

# %% [markdown]
# **Stopword Removal**

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\A.ANGGADIPA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

df['tokens'] = df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])
df
# Out:
#                         at                                            content  \
# 0      2025-09-21 05:18:41                                          รวดเร็วดี
# 1      2025-09-21 04:27:43                              ชอบครับเร็วทันใจจริงๆ
# 2      2025-09-21 03:56:01                                สแกนใบหน้ายากชิบหาย
# 3      2025-09-21 03:37:50                แย่จัด รีเซ็ทเครื่องแล้วทำแอบไม่ได้
# 4      2025-09-21 02:24:04                                                 ดี
# ...                    ...                                                ...
# 99995  2021-06-04 06:14:35               จะเข้าใช้งานก็เข้าไม่ได้ คือไรวะ กาก
# 99996  2021-06-04 06:13:43  เข้าแอปไม่ได้ ลบแล้วโหลดใหม่ ชอบบอกว่ากรุณาทำร...
# 99997  2021-06-04 06:08:17                                      แอพช้าไปหน่อย
# 99998  2021-06-04 06:02:29                                             ดีครับ
# 99999  2021-06-04 05:53:52  ทำไมเข้าแอปไม่ได้มาหลายวันแล้ว มันขึ้นบอกว่าให...
#
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 99995           I can't log in and use it. What's wrong?
# 99996  Can't enter the app Delete and reload I like t...
# 99997                             The app is a bit slow.
# 99998                                               good
# 99999  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 99995            i cannot login and use it what is wrong
# 99996  cannot enter the app delete and reload i like ...
# 99997                              the app is a bit slow
# 99998                                               good
# 99999  why have not i been able to access the app for...
#
#                                                   tokens
# 0                                                 [fast]
# 1                                   [like, really, fast]
# 2                           [scanning, faces, difficult]
# 3                         [bad, reset, device, use, app]
# 4                                                 [good]
# ...                                                  ...
# 99995                                [login, use, wrong]
# 99996  [enter, app, delete, reload, like, say, please...
# 99997                                   [app, bit, slow]
# 99998                                             [good]
# 99999  [able, access, app, several, days, says, make,...
#
# [98939 rows x 5 columns]

# %%
texts = df['tokens'].tolist()

# %% [markdown]
# **Bigram and Trigram**

# %%
from gensim.models import Phrases
from gensim.models.phrases import Phraser

bigram = Phrases(texts, min_count=5, threshold=100)
trigram = Phrases(bigram[texts], threshold=100)

bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)

texts_bi_tri = [trigram_mod[bigram_mod[doc]] for doc in texts]

# %% [markdown]
# **Lemmatization**

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\A.ANGGADIPA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\A.ANGGADIPA\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

texts_lemmatized = [[lemmatizer.lemmatize(word) for word in doc] for doc in texts_bi_tri]

# %% [markdown]
# **Final Cleanup**

# %%
def final_cleanup(tokens):
    return [t for t in tokens if t not in stop_words and len(t) > 2 and t.isalpha()]

df['tokens'] = [final_cleanup(doc) for doc in texts_lemmatized]

# %%
emptyRow = len(df[df['tokens'].str.len() == 0])
print(f"Number of reviews with empty tokens [ ]: {emptyRow}")
# Out:
# Number of reviews with empty tokens [ ]: 1756

# %%
df = df[df['tokens'].str.len() > 0]
df.reset_index(drop=True, inplace=True)
print(f"Number of rows remaining after removing empty tokens: {len(df)}")
# Out:
# Number of rows remaining after removing empty tokens: 97183

# %% [markdown]
# **Visualization after Pre-Processing**

# %%
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt

all_tokens = [word for tokens in df['tokens'] for word in tokens]
word_freq = Counter(all_tokens).most_common(20)

freq_df = pd.DataFrame(word_freq, columns=['Kata', 'Frekuensi'])
plt.figure(figsize=(10,6))
sns.barplot(y='Kata', x='Frekuensi', data=freq_df, palette='Blues_r')
plt.title("20 Most Frequent Words after Pre-Processing")
plt.xlabel("Frekuensi")
plt.ylabel("Kata")
plt.show()
# Out:
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\3643695166.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Kata', x='Frekuensi', data=freq_df, palette='Blues_r')

# %%
print("Number of rows after pre-processing:", len(df))
df
# Out:
# Number of rows after pre-processing: 97183
#                         at                                            content  \
# 0      2025-09-21 05:18:41                                          รวดเร็วดี
# 1      2025-09-21 04:27:43                              ชอบครับเร็วทันใจจริงๆ
# 2      2025-09-21 03:56:01                                สแกนใบหน้ายากชิบหาย
# 3      2025-09-21 03:37:50                แย่จัด รีเซ็ทเครื่องแล้วทำแอบไม่ได้
# 4      2025-09-21 02:24:04                                                 ดี
# ...                    ...                                                ...
# 97178  2021-06-04 06:14:35               จะเข้าใช้งานก็เข้าไม่ได้ คือไรวะ กาก
# 97179  2021-06-04 06:13:43  เข้าแอปไม่ได้ ลบแล้วโหลดใหม่ ชอบบอกว่ากรุณาทำร...
# 97180  2021-06-04 06:08:17                                      แอพช้าไปหน่อย
# 97181  2021-06-04 06:02:29                                             ดีครับ
# 97182  2021-06-04 05:53:52  ทำไมเข้าแอปไม่ได้มาหลายวันแล้ว มันขึ้นบอกว่าให...
#
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 97178           I can't log in and use it. What's wrong?
# 97179  Can't enter the app Delete and reload I like t...
# 97180                             The app is a bit slow.
# 97181                                               good
# 97182  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 97178            i cannot login and use it what is wrong
# 97179  cannot enter the app delete and reload i like ...
# 97180                              the app is a bit slow
# 97181                                               good
# 97182  why have not i been able to access the app for...
#
#                                                   tokens
# 0                                                 [fast]
# 1                                   [like, really, fast]
# 2                            [scanning, face, difficult]
# 3                         [bad, reset, device, use, app]
# 4                                                 [good]
# ...                                                  ...
# 97178                                [login, use, wrong]
# 97179  [enter, app, delete, reload, like, say, please...
# 97180                                   [app, bit, slow]
# 97181                                             [good]
# 97182  [able, access, app, several, day, say, make, n...
#
# [97183 rows x 5 columns]

# %% [markdown]
# # **Transformation**

# %% [markdown]
# ## **Topic Modeling (LDA)**

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from gensim) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel
from pprint import pprint
import ast

# %% [markdown]
# ### **Finding the Optimal Number of Topics Based on the Coherence Score**

# %%
def ensure_list(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return x.split()  
    elif isinstance(x, list):
        return x
    else:
        return []
    
texts = df['tokens'].dropna().apply(ensure_list).tolist()

# %%
dictionary = corpora.Dictionary(texts)

dictionary.filter_extremes(no_below=50, no_above=0.3) 

corpus = [dictionary.doc2bow(text) for text in texts]

# %%
def compute_coherence_values(dictionary, corpus, texts, start, limit, step):
    coherence_values = []
    model_list = []
    
    for num_topics in range(start, limit, step):
        model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=num_topics,
            random_state=100,
            update_every=1,
            chunksize=2000,
            passes=15,
            alpha='auto',
            per_word_topics=True
        )
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        print(f"Jumlah topik = {num_topics}, Coherence = {coherencemodel.get_coherence():.4f}")
    
    return model_list, coherence_values

# %%
start, limit, step = 2, 11, 1  
model_list, coherence_values = compute_coherence_values(dictionary, corpus, texts, start, limit, step)
# Out:
# Jumlah topik = 2, Coherence = 0.5137
# Jumlah topik = 3, Coherence = 0.6086
# Jumlah topik = 4, Coherence = 0.6646
# Jumlah topik = 5, Coherence = 0.5993
# Jumlah topik = 6, Coherence = 0.6181
# Jumlah topik = 7, Coherence = 0.5671
# Jumlah topik = 8, Coherence = 0.5732
# Jumlah topik = 9, Coherence = 0.5825
# Jumlah topik = 10, Coherence = 0.5654

# %%
x = range(start, limit, step)
plt.figure(figsize=(8, 5))
plt.plot(x, coherence_values, marker='o')
plt.title('K PLUS (Thailand)')
plt.xlabel('# of Topics')
plt.ylabel('Coherence Score')
plt.grid(True)
plt.show()

# %% [markdown]
# For K PLUS (Thailand), it was found that the ideal number of topics is 4

# %% [markdown]
# ### **Train the LDA model using the optimal number of topics**

# %%
num_topics = 4
lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    random_state=100,
    update_every=1,
    chunksize=2000,
    passes=15,
    alpha='auto',
    per_word_topics=True
)

# %%
threshold = 0.35

dominant_topics = []
topic_scores = []

for bow in corpus:
    topic_probabilities = lda_model.get_document_topics(bow, minimum_probability=0)
    topic_probabilities = sorted(topic_probabilities, key=lambda x: x[1], reverse=True)

    top_topic, top_score = topic_probabilities[0]

    if top_score < threshold:
        dominant_topics.append(None)
        topic_scores.append(top_score)
    else:
        dominant_topics.append(top_topic)
        topic_scores.append(top_score)

df["lda_topic"] = dominant_topics
df["lda_topic_score"] = topic_scores

print(df["lda_topic"].value_counts(dropna=False))
# Out:
# lda_topic
# 3.0    32191
# 0.0    28764
# 1.0    16174
# 2.0    11835
# NaN     8219
# Name: count, dtype: int64
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\1708725575.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lda_topic"] = dominant_topics
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\1708725575.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lda_topic_score"] = topic_scores

# %%
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.074*"time" + 0.040*"bad" + 0.037*"like" + 0.036*"problem" + '
#   '0.034*"system" + 0.033*"often" + 0.031*"day" + 0.030*"delete" + '
#   '0.023*"every" + 0.023*"transaction"'),
#  (1,
#   '0.209*"app" + 0.056*"please" + 0.052*"update" + 0.052*"slow" + '
#   '0.051*"access" + 0.037*"enter" + 0.034*"fix" + 0.021*"improve" + '
#   '0.018*"help" + 0.017*"updated"'),
#  (2,
#   '0.065*"money" + 0.059*"bank" + 0.037*"account" + 0.033*"new" + '
#   '0.032*"transfer" + 0.026*"want" + 0.023*"phone" + 0.023*"number" + '
#   '0.017*"well" + 0.015*"one"'),
#  (3,
#   '0.371*"good" + 0.263*"use" + 0.062*"convenient" + 0.049*"easy" + '
#   '0.046*"service" + 0.030*"fast" + 0.025*"much" + 0.023*"thank" + '
#   '0.016*"excellent" + 0.014*"yes"')]

# %% [markdown]
# **Intertopic Distance Map Visualization**

# %%
pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.0.2)
# Requirement already satisfied: scipy in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.15.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: numexpr in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.14.1)
# Requirement already satisfied: funcy in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: gensim in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (4.4.0)
# Requirement already satisfied: setuptools in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pyLDAvis) (75.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from gensim->pyLDAvis) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from smart_open>=1.8.1->gensim->pyLDAvis) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\a.anggadipa\appdata\local\programs\python\python312\lib\site-packages (from jinja2->pyLDAvis) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyLDAvis
import pyLDAvis.gensim

pyLDAvis.enable_notebook()
lda_display = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el586412253632087846591548320" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el586412253632087846591548320_data = {"mdsDat": {"x": [-0.15085989992868878, -0.11000295372695135, -0.1658037716596026, 0.42666662531524274], "y": [0.29958584702190677, -0.368607370572145, 0.04186131371393154, 0.02716020983630675], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [34.905865369082754, 26.81875826962888, 25.275239278718658, 13.000137082569708]}, "tinfo": {"Term": ["good", "app", "use", "time", "money", "bank", "please", "update", "slow", "access", "convenient", "bad", "like", "problem", "enter", "easy", "account", "system", "service", "fix", "often", "new", "day", "delete", "transfer", "want", "every", "transaction", "phone", "fast", "time", "bad", "problem", "system", "often", "like", "day", "delete", "every", "transaction", "get", "used", "login", "reload", "able", "really", "many", "download", "unable", "lot", "always", "crash", "long", "reinstall", "turn", "deleted", "waste", "several", "complete", "machine", "work", "using", "make", "still", "suck", "say", "could", "please", "update", "slow", "access", "enter", "fix", "improve", "help", "updated", "wrong", "difficult", "app", "updating", "quickly", "better", "version", "sometimes", "urgently", "hurry", "slowly", "install", "stuck", "accessed", "keep", "banking", "latest", "scan", "bounce", "week", "urgent", "press", "apps", "anything", "know", "take", "right", "since", "open", "money", "bank", "account", "transfer", "want", "phone", "number", "new", "well", "one", "card", "apply", "change", "would", "another", "already", "come", "information", "pay", "withdraw", "give", "star", "customer", "freeze", "old", "mobile", "let", "transferring", "yet", "changed", "see", "device", "going", "good", "convenient", "easy", "service", "fast", "use", "much", "thank", "excellent", "yes", "great", "comfortable", "fresh", "safe", "superb", "badly", "love", "useful", "impressive", "satisfied", "hassle", "impressed", "provide", "prompt", "happy", "personally", "job", "spending", "level", "quality", "everything"], "Freq": [23963.0, 27886.0, 17001.0, 12798.0, 8174.0, 7444.0, 7459.0, 6927.0, 6903.0, 6746.0, 3996.0, 6946.0, 6464.0, 6317.0, 4959.0, 3182.0, 4605.0, 5955.0, 2946.0, 4556.0, 5674.0, 4187.0, 5443.0, 5283.0, 4039.0, 3309.0, 4075.0, 3951.0, 2935.0, 1946.0, 12798.111762069173, 6945.983071537436, 6316.284870179223, 5955.012657789165, 5673.851176352638, 6463.746291138972, 5442.393904641002, 5282.832990621176, 4074.413442458834, 3950.8454436577144, 3207.440948899412, 3124.5087578994376, 2924.773935090076, 2884.241812311817, 2872.39200312305, 2804.055174877358, 2112.5251691859144, 2037.8264088194692, 2030.704119864219, 1892.1169740408213, 1817.497834727776, 1692.3259481349423, 1692.4396463531848, 1483.223781069493, 1354.1074222703428, 1348.9409364726455, 1288.300137125821, 1205.5665950014688, 1187.7800107367266, 1110.3767186050973, 3361.20163875736, 2574.5482152161453, 2653.804756004498, 3789.550308803387, 1605.7856152404268, 1853.0193222489688, 1608.5316533153955, 7459.040310625533, 6926.9951667982195, 6902.874422334414, 6745.34085103119, 4959.027914615556, 4555.308585877769, 2833.420377545298, 2346.6418953528864, 2246.793220680802, 2109.403699711211, 1998.1168178212245, 27874.977996232, 1314.5313113087986, 1316.64920370189, 1262.077241595328, 1088.3544750295173, 1107.240173666505, 1104.540692238587, 917.4318232833984, 884.9577627889793, 886.668964748607, 886.922595639835, 735.2823440763277, 718.480290216982, 701.7329580910175, 682.8737517217781, 675.5716265400088, 668.575558399929, 721.7062046468736, 681.5021099059104, 1466.5814174876318, 1318.9255533592172, 2189.131900306675, 1508.5797894728005, 1048.6861817505512, 852.3884045820049, 900.7614242066323, 855.664573665002, 8174.130591319314, 7444.286961144276, 4604.787049143871, 4038.325851905125, 3308.4859639374126, 2935.038932787296, 2869.2951328352588, 4185.939558725084, 2083.5950822371356, 1868.1512948813715, 1782.6406880619984, 1746.212872519239, 1485.6538522593683, 1500.6436145321768, 1392.11971904692 ...

# %% [markdown]
# The four topics identified for K PLUS are located in different quadrants with no overlap, indicating a clear distinction between the identified aspects.

# %%
df.isnull().sum()
# Out:
# at                       0
# content                  0
# content_translated       0
# cleaned                  0
# tokens                   0
# lda_topic             8219
# lda_topic_score          0
# dtype: int64

# %%
df[["content_translated", "cleaned", "tokens", "lda_topic", "lda_topic_score"]]
# Out:
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 97178           I can't log in and use it. What's wrong?
# 97179  Can't enter the app Delete and reload I like t...
# 97180                             The app is a bit slow.
# 97181                                               good
# 97182  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 97178            i cannot login and use it what is wrong
# 97179  cannot enter the app delete and reload i like ...
# 97180                              the app is a bit slow
# 97181                                               good
# 97182  why have not i been able to access the app for...
#
#                                                   tokens  lda_topic  \
# 0                                                 [fast]        3.0
# 1                                   [like, really, fast]        0.0
# 2                            [scanning, face, difficult]        1.0
# 3                         [bad, reset, device, use, app]        0.0
# 4                                                 [good]        3.0
# ...                                                  ...        ...
# 97178                                [login, use, wrong]        NaN
# 97179  [enter, app, delete, reload, like, say, please...        1.0
# 97180                                   [app, bit, slow]        1.0
# 97181                                             [good]        3.0
# 97182  [able, access, app, several, day, say, make, n...        0.0
#
#        lda_topic_score
# 0             0.356898
# 1             0.478747
# 2             0.589020
# 3             0.394767
# 4             0.356901
# ...                ...
# 97178         0.333503
# 97179         0.474018
# 97180         0.589029
# 97181         0.356901
# 97182         0.596906
#
# [97183 rows x 5 columns]

# %% [markdown]
# ## **Aspect Extraction**

# %% [markdown]
# **Topic Labeling**

# %%
topic_labels = {
    0: "system stability",
    1: "access",
    2: "feature",
    3: "usability"
}

df["aspect"] = df["lda_topic"].map(topic_labels)
df["aspect"] = df["aspect"].fillna("unknown")
df[["content_translated", "cleaned", "tokens", "aspect"]]
# Out:
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\1656133699.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aspect"] = df["lda_topic"].map(topic_labels)
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\1656133699.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aspect"] = df["aspect"].fillna("unknown")
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 97178           I can't log in and use it. What's wrong?
# 97179  Can't enter the app Delete and reload I like t...
# 97180                             The app is a bit slow.
# 97181                                               good
# 97182  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 97178            i cannot login and use it what is wrong
# 97179  cannot enter the app delete and reload i like ...
# 97180                              the app is a bit slow
# 97181                                               good
# 97182  why have not i been able to access the app for...
#
#                                                   tokens            aspect
# 0                                                 [fast]         usability
# 1                                   [like, really, fast]  system stability
# 2                            [scanning, face, difficult]            access
# 3                         [bad, reset, device, use, app]  system stability
# 4                                                 [good]         usability
# ...                                                  ...               ...
# 97178                                [login, use, wrong]           unknown
# 97179  [enter, app, delete, reload, like, say, please...            access
# 97180                                   [app, bit, slow]            access
# 97181                                             [good]         usability
# 97182  [able, access, app, several, day, say, make, n...  system stability
#
# [97183 rows x 4 columns]

# %% [markdown]
# **Visualization of Review Distribution by Aspect**

# %%
plt.figure(figsize=(15, 6))

# Histogram
plt.subplot(1, 2, 1)
df["aspect"].value_counts().plot(kind="bar", color="steelblue")
plt.title("Distribution of Reviews by Aspect")
plt.xlabel("Aspect")
plt.ylabel("Number of Reviews")
plt.xticks(rotation=45)

# Pie Chart
plt.subplot(1, 2, 2)
aspect_counts = df["aspect"].value_counts()
plt.pie(aspect_counts, labels=aspect_counts.index, autopct='%1.1f%%', 
    colors=['steelblue', 'lightcoral', 'lightgreen', 'orange', 'lightgray'])
plt.title("Distribution of Reviews by Aspect")
plt.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Data Mining**

# %% [markdown]
# ## **VADER Sentiment Labeling**

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\A.ANGGADIPA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def get_sentiment_label(text):
    score = sia.polarity_scores(text)
    compound = score['compound']
    if compound >= 0.05:
        return "positive"
    elif compound <= -0.05:
        return "negative"
    else:
        return "neutral"

# %%
df["sentiment"] = df["cleaned"].apply(get_sentiment_label)

df[["content_translated", "cleaned", "tokens", "sentiment", "aspect"]]
# Out:
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\2825488844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sentiment"] = df["cleaned"].apply(get_sentiment_label)
#                                       content_translated  \
# 0                                              Very fast
# 1                           I like it, it's really fast.
# 2                           Scanning faces is difficult.
# 3      Very bad, reset the device and can't use the app.
# 4                                                   good
# ...                                                  ...
# 97178           I can't log in and use it. What's wrong?
# 97179  Can't enter the app Delete and reload I like t...
# 97180                             The app is a bit slow.
# 97181                                               good
# 97182  Why haven't I been able to access the app for ...
#
#                                                  cleaned  \
# 0                                              very fast
# 1                            i like it it is really fast
# 2                            scanning faces is difficult
# 3       very bad reset the device and cannot use the app
# 4                                                   good
# ...                                                  ...
# 97178            i cannot login and use it what is wrong
# 97179  cannot enter the app delete and reload i like ...
# 97180                              the app is a bit slow
# 97181                                               good
# 97182  why have not i been able to access the app for...
#
#                                                   tokens sentiment  \
# 0                                                 [fast]   neutral
# 1                                   [like, really, fast]  positive
# 2                            [scanning, face, difficult]  negative
# 3                         [bad, reset, device, use, app]  negative
# 4                                                 [good]  positive
# ...                                                  ...       ...
# 97178                                [login, use, wrong]  negative
# 97179  [enter, app, delete, reload, like, say, please...  positive
# 97180                                   [app, bit, slow]   neutral
# 97181                                             [good]  positive
# 97182  [able, access, app, several, day, say, make, n...   neutral
#
#                  aspect
# 0             usability
# 1      system stability
# 2                access
# 3      system stability
# 4             usability
# ...                 ...
# 97178           unknown
# 97179            access
# 97180            access
# 97181         usability
# 97182  system stability
#
# [97183 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(data=df, x="aspect", hue="sentiment")
plt.title("Sentiment Distribution by Aspect")
plt.show()

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# positive    51097
# neutral     24691
# negative    21395
# Name: count, dtype: int64

# %%
# Percentage
df["sentiment"].value_counts(normalize=True).round(3)
# Out:
# sentiment
# positive    0.526
# neutral     0.254
# negative    0.220
# Name: proportion, dtype: float64

# %%
df = df[df["aspect"] != "unknown"]
print("Number of rows in the dataset after the unknown aspect is excluded:", len(df))
# Out:
# Number of rows in the dataset after the unknown aspect is excluded: 88964

# %% [markdown]
# Neutral reviews were excluded from the dataset because they often contain ambiguous feedback that lacks strong emotional polarization, making it difficult to identify clear problem areas or satisfaction factors.

# %%
df = df[df["sentiment"] != "neutral"]
print("Number of rows in the dataset after neutral sentiment has been excluded:", len(df))
# Out:
# Number of rows in the dataset after neutral sentiment has been excluded: 67471

# %% [markdown]
# ## **Application of the Classification Model to the Entire Dataset**

# %% [markdown]
# **TF-IDF & Split Dataset**

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

X = df['cleaned']
y = df['sentiment']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.25, random_state=42)

# %%
tfidf = TfidfVectorizer(max_features=5000) 
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %% [markdown]
# **Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear', random_state=42)

svm_model.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = svm_model.predict(X_test_tfidf)

# %% [markdown]
# **Confusion Matrix Evaluation**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_,
            annot_kws={"size":16, "weight":"bold"})
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('K PLUS (Thailand)')
plt.show()

# %% [markdown]
# **Classification Report**

# %%
from sklearn.metrics import classification_report

classification_report(y_test, y_pred, target_names=le.classes_, digits=4)
# Out:
# '              precision    recall  f1-score   support\n\n    negative     0.8986    0.9038    0.9012      5041\n    positive     0.9589    0.9565    0.9577     11827\n\n    accuracy                         0.9408     16868\n   macro avg     0.9288    0.9302    0.9295     16868\nweighted avg     0.9409    0.9408    0.9408     16868\n'

# %% [markdown]
# **ROC-AUC Evaluation**

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# %%
y_score = svm_model.decision_function(X_test_tfidf)

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.4f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('K PLUS (Thailand)')
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %% [markdown]
# ## **Application of the Classification Model to Each Aspect**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc

# %%
def svm_each_aspect(df):
    results = []
    
    df_bin = df[df['sentiment'].str.lower().isin(['positive', 'negative'])].copy()
    unique_aspects = df_bin['aspect'].dropna().unique()
    
    cm_data = {}
    roc_data = {}
    le_classes = {}
    
    for aspect in unique_aspects:
        df_subset = df_bin[df_bin['aspect'] == aspect].copy()
        
        X = df_subset['cleaned']
        y = df_subset['sentiment'].str.lower() 
        
        # TF-IDF & Split Dataset
        le = LabelEncoder()
        y_encoded = le.fit_transform(y)
            
        X_train, X_test, y_train, y_test = train_test_split(
            X, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded
        )
        
        tfidf = TfidfVectorizer(max_features=5000)
        X_train_tfidf = tfidf.fit_transform(X_train)
        X_test_tfidf = tfidf.transform(X_test)
        
        # SVM Modeling
        svm_model = SVC(kernel='linear', random_state=42)
        svm_model.fit(X_train_tfidf, y_train)
        
        y_pred = svm_model.predict(X_test_tfidf)
        y_score = svm_model.decision_function(X_test_tfidf)
        
        # Evaluation
        acc = accuracy_score(y_test, y_pred)
        report = classification_report(y_test, y_pred, target_names=le.classes_, output_dict=True)
        acc_str = f"{acc * 100:.2f}%"
        
        if 'positive' in report:
            results.append({
                'Aspect': aspect.title(),
                'Sentiment': 'Positive',
                'Precision': round(report['positive']['precision'], 4),
                'Recall': round(report['positive']['recall'], 4),
                'F1-Score': round(report['positive']['f1-score'], 4),
                'Accuracy': acc_str
            })
            
        if 'negative' in report:
            results.append({
                'Aspect': aspect.title(),
                'Sentiment': 'Negative',
                'Precision': round(report['negative']['precision'], 4),
                'Recall': round(report['negative']['recall'], 4),
                'F1-Score': round(report['negative']['f1-score'], 4),
                'Accuracy': acc_str
            })
            
        cm_data[aspect] = confusion_matrix(y_test, y_pred)
        le_classes[aspect] = le.classes_
        
        fpr, tpr, _ = roc_curve(y_test, y_score)
        roc_data[aspect] = (fpr, tpr, auc(fpr, tpr))
            
    df_results = pd.DataFrame(results)
    df_display = df_results.copy()
    
    df_display.loc[df_display.duplicated('Aspect'), ['Aspect', 'Accuracy']] = ''
    
    display(df_display)

    num_aspects = len(cm_data)
    cols = 4
    rows = math.ceil(num_aspects / cols)
    
    fig_cm, axes_cm = plt.subplots(rows, cols, figsize=(16, 4 * rows))
    
    if num_aspects > 1:
        axes_cm = axes_cm.flatten()
    else:
        axes_cm = [axes_cm]
    
    for idx, (aspect, cm) in enumerate(cm_data.items()):
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes_cm[idx],
                    xticklabels=le_classes[aspect], yticklabels=le_classes[aspect],
                    annot_kws={"size": 16, "weight": "bold"})
        axes_cm[idx].set_title(f'Aspect: {aspect.title()}', fontweight='bold', fontsize=12)
        axes_cm[idx].set_xlabel('Predicted', fontsize=12)
        axes_cm[idx].set_ylabel('Actual', fontsize=12)
        
    for i in range(num_aspects, len(axes_cm)):
        fig_cm.delaxes(axes_cm[i])
        
    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(10, 8))
    colors = plt.cm.get_cmap('tab10', len(roc_data))
    
    for idx, (aspect, (fpr, tpr, roc_auc)) in enumerate(roc_data.items()):
        plt.plot(fpr, tpr, lw=2, color=colors(idx), 
                 label=f'{aspect.title()} (AUC = {roc_auc:.4f})')
        
    plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title(f'ROC Curve per Aspect', fontsize=16)
    plt.legend(loc="lower right", fontsize=16)
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
results = svm_each_aspect(df)
results
# Out:
#              Aspect Sentiment  Precision  Recall  F1-Score Accuracy
# 0  System Stability  Positive     0.9039  0.8796    0.8916   90.44%
# 1                    Negative     0.9048  0.9244    0.9145
# 2            Access  Positive     0.8442  0.8364    0.8403   85.99%
# 3                    Negative     0.8720  0.8783    0.8752
# 4         Usability  Positive     0.9975  0.9993    0.9984   99.68%
# 5                    Negative     0.9275  0.7711    0.8421
# 6           Feature  Positive     0.8772  0.8853    0.8812   86.46%
# 7                    Negative     0.8478  0.8375    0.8426
# C:\Users\A.ANGGADIPA\AppData\Local\Temp\ipykernel_5864\3452465660.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(roc_data))

# %% [markdown]
# As a note regarding the evaluation results for this aspect, no data balancing (resampling) techniques were used in this study. This decision was based on two grounds. First, from an algorithmic perspective, referring to the findings of Basri et al. (2026), the application of resampling (such as SMOTE) to SVM models actually risks distorting the distribution of the minority class and compromising the accuracy of the model’s hyperplane, which could ultimately reduce classification performance. Second, from a methodological perspective, maintaining the data distribution in its original proportions is crucial because this study is oriented toward extracting insights and understanding user behavior patterns. As supported by the research of Zafira et al. (2025), allowing the imbalance in review data to remain natural is an essential step for capturing field realities proportionally in order to gain strategic insights.

# %% [markdown]
# Basri, H., Purwanti, W. N., & Alparisi, I. (2026). Evaluating SMOTE Performance for Imbalanced Multi-Label Sentiment Classification in MLSE Usability Testing of Mobile App Reviews. Jurnal Teknik Informatika (Jutif), 7(2), 937–947. https://doi.org/10.52436/1.jutif.2026.7.2.5351
#
# Zafira, Z. T., Tania, K. D., & Sari, W. K. (2025). Sentiment-Based Knowledge Discovery of Wondr by BNI App Reviews Using SVM, KNN, and Naive Bayes for CRM Enhancement. Journal of Applied Informatics and Computing (JAIC), 9(5), 2498–2508. http://jurnal.polibatam.ac.id/index.php/JAIC
